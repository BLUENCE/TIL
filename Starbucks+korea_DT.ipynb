# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/BLUENCE/TIL/blob/master/Starbucks+korea_DT.ipynb)

# %%
import pandas as pd
import re

# %%
% pwd
# Out:
# '/Users/jieun/projects/StarbucksDT'

# %% [markdown]
# # 주거 인구수 데이터 분석하기
#
# - 전국의 읍/면/동 별로 주거 인구수 파싱해서 folium으로 색상 시각화해서 나타내기

# %% [markdown]
# ## Tidy Data로 전처리하기
#
# 열도 아닌 이상한것이 첫번째 행에 들어가 있어서 엑셀에서 외부에서 데이터 가져오기로 열어서 삭제 해주고 판다스로 불러왔다.
#
# 참고주소 : https://support.office.com/ko-kr/article/mac%EC%9A%A9-excel%EA%B3%BC-%ED%98%B8%ED%99%98%EB%90%98%EB%8A%94-odbc-%EB%93%9C%EB%9D%BC%EC%9D%B4%EB%B2%84-9fa6bc7f-d19e-4f7f-9be4-92e85c77d712?ui=ko-KR&rs=ko-KR&ad=KR

# %%
df_data = pd.read_csv("data/2015_인구자료.csv")

# %%
df_2015 = df_data.copy()
df_2015.shape
# Out:
# (3819, 23)

# %%
df_2015['행정구역별(읍면동)'].value_counts().head(3) # 동 이름만 뽑아와서는 나중에 지도에 위경도를 못 찍을 것 같다.
# Out:
#   중앙동    31
#   남면     15
#  동부      14
# Name: 행정구역별(읍면동), dtype: int64

# %%
df_2015['C행정구역별(읍면동)']
# Out:
# 0            '00
# 1            '04
# 2            '05
# 3            '03
# 4            '11
# 5         '11010
# 6       '1101053
# 7       '1101054
# 8       '1101055
# 9       '1101056
# 10      '1101057
# 11      '1101058
# 12      '1101060
# 13      '1101061
# 14      '1101063
# 15      '1101064
# 16      '1101067
# 17      '1101068
# 18      '1101069
# 19      '1101070
# 20      '1101071
# 21      '1101072
# 22      '1101073
# 23        '11020
# 24      '1102052
# 25      '1102054
# 26      '1102055
# 27      '1102057
# 28      '1102058
# 29      '1102059
#           ...
# 3789    '3901058
# 3790    '3901059
# 3791    '3901060
# 3792    '3901061
# 3793    '3901062
# 3794    '3901063
# 3795    '3901064
# 3796    '3901065
# 3797    '3901066
# 3798    '3901067
# 3799    '3901068
# 3800    '3901069
# 3801      '39020
# 3802    '3902011
# 3803    '3902012
# 3804    '3902013
# 3805    '3902031
# 3806    '3902032
# 3807    '3902051
# 3808    '3902052
# 3809    '3902053
# ...

# %%
# 앞에 신경쓰이는 ' 표시는 삭제한다

df_2015['C행정구역별(읍면동)'] = df_2015['C행정구역별(읍면동)'].str.extract(r'^\'(\d+)', expand = False)

# %%
df_2015['C행정구역별(읍면동)'].head(10)
# Out:
# 0         00
# 1         04
# 2         05
# 3         03
# 4         11
# 5      11010
# 6    1101053
# 7    1101054
# 8    1101055
# 9    1101056
# Name: C행정구역별(읍면동), dtype: object

# %%
#  행 드랍은 그냥해도 괜찮다, 열 드랍은 axis = 1 
# f.drop(df.index[2])
# df_2015['C행정구역별(읍면동)'].drop(df_2015.index[:5])

# %%
df_2015['C행정구역별(읍면동)'][5][0:2]  # 시 뽑아내기
# Out:
# '11'

# %%
# 이 방법은 좀 느리다

#for i in range(len(df_2015['C행정구역별(읍면동)'][5:])):
    #df_2015.loc[df_2015['C행정구역별(읍면동)'].str.contains(r'^11'), '시'] = '서울특별시'

# %%
# 시 전처리 

df_2015['시'] = df_2015['C행정구역별(읍면동)'].copy()

df_2015['시'].replace(r"(^11\d+)","서울특별시",inplace = True, regex = True ) 
df_2015['시'].replace(r"(^21\d+)","부산광역시",inplace = True, regex = True ) 

df_2015['시'].replace(r"(^22\d+)","대구광역시",inplace = True, regex = True ) 
df_2015['시'].replace(r"(^23\d+)","인천광역시",inplace = True, regex = True ) 

df_2015['시'].replace(r"(^24\d+)","광주광역시",inplace = True, regex = True ) 
df_2015['시'].replace(r"(^25\d+)","대전광역시",inplace = True, regex = True ) 

df_2015['시'].replace(r"(^26\d+)","울산광역시",inplace = True, regex = True ) 
df_2015['시'].replace(r"(^29\d+)","세종특별자치시",inplace = True, regex = True ) 

df_2015['시'].replace(r"(^31\d+)","경기도",inplace = True, regex = True ) 
df_2015['시'].replace(r"(^32\d+)","강원도",inplace = True, regex = True ) 

df_2015['시'].replace(r"(^33\d+)","충청북도",inplace = True, regex = True ) 
df_2015['시'].replace(r"(^34\d+)","충청남도",inplace = True, regex = True ) 

df_2015['시'].replace(r"(^35\d+)","전라북도",inplace = True, regex = True ) 
df_2015['시'].replace(r"(^36\d+)","전라남도",inplace = True, regex = True ) 

df_2015['시'].replace(r"(^37\d+)","경상북도",inplace = True, regex = True ) 
df_2015['시'].replace(r"(^38\d+)","경상남도",inplace = True, regex = True ) 

df_2015['시'].replace(r"(^39\d+)","제주특별자치도",inplace = True, regex = True )

# %%
#df_2015['시']

# %%
df_2015['C행정구역별(읍면동)'][6][2:5]  # 구 뽑아내기
# Out:
# '010'

# %%
# '구' 이름을 나타내는 자료만 넣은 컬럼 = copy행정구역별(읍면동)
df_2015['Copy행정구역별(읍면동)'] = df_2015['C행정구역별(읍면동)'][df_2015['C행정구역별(읍면동)'].str.match(r'^\d\d\d\d\d$') == True]
df_2015['구'] = None  # 일부러 Na 값으로 만들어준다. 나중에 채워주려고

# %%
#df_2015['구'].isnull().sum()

# %%
# 앞에 값으로 값 채우기 df.fillna(method='ffill') # Fill values forward

df_2015['Copy행정구역별(읍면동)'] = df_2015['Copy행정구역별(읍면동)'].fillna(method='ffill')
df_2015['Copy행정구역별(읍면동)'] = df_2015['Copy행정구역별(읍면동)'].fillna(0)

# %%
#df_2015[['Copy행정구역별(읍면동)','C행정구역별(읍면동)']][5:].head(30)

# %%
for i in range(len(df_2015)):

    if df_2015['C행정구역별(읍면동)'][i] == df_2015['Copy행정구역별(읍면동)'][i]:
        df_2015['구'][i] = df_2015['행정구역별(읍면동)'][i]
# Out:
# /Users/jieun/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
df_2015['구'][5:20]
# Out:
# 5      종로구
# 6      종로구
# 7      종로구
# 8      종로구
# 9      종로구
# 10     종로구
# 11     종로구
# 12     종로구
# 13     종로구
# 14     종로구
# 15     종로구
# 16     종로구
# 17     종로구
# 18     종로구
# 19     종로구
# Name: 구, dtype: object

# %%
df_2015['구'] = df_2015['구'].fillna(method='ffill')

# %%
df_2015['구'][5:20]
# Out:
# 5      종로구
# 6      종로구
# 7      종로구
# 8      종로구
# 9      종로구
# 10     종로구
# 11     종로구
# 12     종로구
# 13     종로구
# 14     종로구
# 15     종로구
# 16     종로구
# 17     종로구
# 18     종로구
# 19     종로구
# Name: 구, dtype: object

# %%
df_2015['주소'] = 0


for i in range(len(df_2015)):
    if len(df_2015['C행정구역별(읍면동)'][i]) == 7 :
        df_2015['주소'][i] = df_2015['시'][i] + df_2015['구'][i] + df_2015['행정구역별(읍면동)'][i]
# Out:
# /Users/jieun/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/jieun/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_2015[5:10]
# Out:
#   C행정구역별(읍면동) 행정구역별(읍면동)    시점  총인구 (명)  남자 (명)  여자 (명)  내국인-계 (명)  \
# 5       11010        종로구  2015   161521   79510   82011     146119
# 6     1101053        사직동  2015     9379    4325    5054       8571
# 7     1101054        삼청동  2015     2808    1340    1468       2601
# 8     1101055        부암동  2015    11012    5327    5685      10157
# 9     1101056        평창동  2015    18594    8794    9800      17789
#
#    내국인-남자 (명)  내국인-여자 (명) 외국인-계 (명)       ...       단독주택 (호) 아파트 (호)  \
# 5       71951       74168     15402       ...          13103   12552
# 6        3934        4637       808       ...            729    1532
# 7        1222        1379       207       ...            714       X
# 8        4921        5236       855       ...           1092     121
# 9        8393        9396       805       ...           1533     936
#
#    연립주택 (호)  다세대주택 (호) 비거주용 건물내 주택 (호) 주택이외의 거처 (호)      시 Copy행정구역별(읍면동)  \
# ...

# %%
new_data = df_2015[['주소', '총인구 (명)', '남자 (명)', '여자 (명)',
       '내국인-계 (명)', '내국인-남자 (명)', '내국인-여자 (명)', '외국인-계 (명)', '외국인-남자 (명)',
       '외국인-여자 (명)', '가구-계 (가구)', '일반가구 (가구)', '집단가구 (가구)', '외국인가구 (가구)',
       '주택-계 (호)', '단독주택 (호)', '아파트 (호)', '연립주택 (호)', '다세대주택 (호)',
       '비거주용 건물내 주택 (호)', '주택이외의 거처 (호)']][6:]

df_cleand_2015 = pd.DataFrame(new_data)

# %%
df_cleand_2015 = df_cleand_2015[(df_cleand_2015[['주소']] != 0).all(axis=1)]

df_cleand_2015 = df_cleand_2015.reset_index(drop=True)  # drop을 True 로 해줘야 기존의 인덱스로 대체된다

# %%
df_cleand_2015.to_csv('data/df_cleand_2015.csv')  # 저장

# %%
df_cleand_2015.head()
# Out:
#    Unnamed: 0              주소  총인구 (명)  남자 (명)  여자 (명)  내국인-계 (명)  내국인-남자 (명)  \
# 0           0  서울특별시 종로구  사직동     9379    4325    5054       8571        3934
# 1           1  서울특별시 종로구  삼청동     2808    1340    1468       2601        1222
# 2           2  서울특별시 종로구  부암동    11012    5327    5685      10157        4921
# 3           3  서울특별시 종로구  평창동    18594    8794    9800      17789        8393
# 4           4  서울특별시 종로구  무악동     8106    3829    4277       7981        3785
#
#    내국인-여자 (명) 외국인-계 (명) 외국인-남자 (명)     ...      일반가구 (가구)  집단가구 (가구)  \
# 0        4637       808        391     ...           3562          7
# 1        1379       207        118     ...           1092          X
# 2        5236       855        406     ...           3841          6
# 3        9396       805        401     ...           6310         16
# 4        4196       125         44     ...           2823          X
#
#    외국인가구 (가구) 주택-계 (호) 단독주택 (호)  아파트 (호) 연립주택 (호) 다세대주택 (호) 비거주용 건물내 주택 (호)  \
# ...

# %%
df_cleand_2015 = pd.read_csv('data/df_cleand_2015.csv')

# %% [markdown]
# '''
# 서울특별시 11
#
# 부산광역시 21
#
# 대구광역시 22
#
# 인천광역시 23
#
# 광주광역시 24
#
# 대전광역시 25
#
# 울산광역시 26
#
# 세종특별자치시 29
#
# 경기도 31
#
# 강원도 32
#
# 충청북도 33
#
# 충청남도 34
#
# 전라북도 35
#
# 전라남도 36
#
# 경상북도 37
#
# 경상남도 38
#
# 제주특별자치도 39
# '''

# %% [markdown]
# ## 시각화
# 참고 https://colab.research.google.com/drive/1jJ32ecgNGTkKc2I8w1beWWoq_oaIKxCs

# %%
# !pip install googlemaps
# !pip show googlemaps
# !pip install folium
# !pip show folium
# Out:
# ...
# Name: googlemaps
# Version: 3.0.2
# Summary: Python client library for Google Maps API Web Services
# Home-page: https://github.com/googlemaps/google-maps-services-python
# Author: UNKNOWN
# Author-email: UNKNOWN
# License: Apache 2.0
# Location: /Users/jieun/anaconda3/lib/python3.6/site-packages
# Requires: requests
# Required-by:
# ...
# Name: folium
# Version: 0.5.0
# Summary: Make beautiful maps with Leaflet.js & Python
# Home-page: https://github.com/python-visualization/folium
# Author: Rob Story
# Author-email: wrobstory@gmail.com
# License: Copyright (C) 2013, Rob Story
# Location: /Users/jieun/anaconda3/lib/python3.6/site-packages
# Requires: jinja2, six, requests, branca
# Required-by: ipython-magic-folium

# %% [markdown]
# ### Google Geo-location API 사용하기
# Google Maps Platform - Geo-location API / Google Maps Platform / Google Cloud
#
# 프로젝트 만들기 - 오른쪽 상단 콘솔 클릭
#
# API 및 서비스 - 사용자 인증정보 - API 키 만들기
#
# 라이브러리 - Geocoding API 설정하기(위/경도 받아오기 위함)
#
# 위도/경도 표시해주면 지도상에 표시해줍니다.

# %%
import googlemaps
gmaps_key = 'AIzaSyAmr6_8pbmbDMBt95PYAVe5se5-kIIUOhM' # 자신의 key를 사용합니다.
gmaps = googlemaps.Client(key=gmaps_key)

# %%
# 주소 전처리

name_2015 = df_cleand_2015['주소'].str.replace('\n', '')

# %%
df_seoul = df_cleand_2015.loc[df_cleand_2015['주소'].str.contains('서울특별시')]

# %%
df_seoul.to_csv('df_seoul_2015.csv')

# %%
df_seoul
# Out:
#      Unnamed: 0                      주소  총인구 (명)  남자 (명)  여자 (명)  내국인-계 (명)  \
# 0             0          서울특별시 종로구  사직동     9379    4325    5054       8571
# 1             1          서울특별시 종로구  삼청동     2808    1340    1468       2601
# 2             2          서울특별시 종로구  부암동    11012    5327    5685      10157
# 3             3          서울특별시 종로구  평창동    18594    8794    9800      17789
# 4             4          서울특별시 종로구  무악동     8106    3829    4277       7981
# 5             5          서울특별시 종로구  교남동     4620    2234    2386       4441
# 6             6          서울특별시 종로구  가회동     4917    2417    2500       4616
# 7             7  서울특별시 종로구  종로1·2·3·4가동     7598    4130    3468       6679
# 8             8      서울특별시 종로구  종로5·6가동     5792    3128    2664       5169
# 9             9          서울특별시 종로구  이화동     9519    4505    5014       8618
# 10           10         서울특별시 종로구  창신1동     6766    3519    3247       5316
# ...

# %%
#df_seoul.loc[df_seoul['주소'].str.contains('가')]

# %% [markdown]
# ## "Geocode by Awesome Table" 으로 위/경도 얻기

# %%
data = pd.read_csv('geo_starbucks.csv')
geo_seoul = pd.DataFrame(data)

# %%
geo = geo_seoul[['Latitude', 'Longitude']].drop(0)

# %%
geo = geo.reset_index()

# %%
df_seoul['위도'] = geo['Latitude'][:]
# Out:
# /Users/jieun/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_seoul['경도'] = geo['Longitude'][:]
# Out:
# /Users/jieun/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_seoul.shape
# Out:
# (424, 24)

# %%
df_seoul['juso'] = df_seoul['주소'].str.replace('  ',' ')
# Out:
# /Users/jieun/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
#df_dong['Dong'] = df_seoul['주소'].str.split('\s').str[3]

# %%
#df_dong['Dong']

# %%
df_seoul['counts'] = df_seoul['총인구 (명)']
# Out:
# /Users/jieun/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_seoul[['위도', '경도', 'juso', 'counts']]
# Out:
#             위도          경도                   juso  counts
# 0    37.576164  126.968806          서울특별시 종로구 사직동    9379
# 1    37.584838  126.981913          서울특별시 종로구 삼청동    2808
# 2    37.596261  126.967699          서울특별시 종로구 부암동   11012
# 3    37.605335  126.966858          서울특별시 종로구 평창동   18594
# 4    37.577355  126.958624          서울특별시 종로구 무악동    8106
# 5    37.571839  126.961971          서울특별시 종로구 교남동    4620
# 6    37.580005  126.984691          서울특별시 종로구 가회동    4917
# 7    37.570646  126.988968  서울특별시 종로구 종로1·2·3·4가동    7598
# 8    37.572020  127.005008      서울특별시 종로구 종로5·6가동    5792
# 9    37.576923  127.004300          서울특별시 종로구 이화동    9519
# 10   37.575091  127.012158         서울특별시 종로구 창신1동    6766
# 11   37.574424  127.010827         서울특별시 종로구 창신2동   11405
# 12   37.575091  127.012158         서울특별시 종로구 창신3동    7603
# 13   37.577728  127.015660         서울특별시 종로구 숭인1동    7049
# 14   37.574840  127.019938         서울특별시 종로구 숭인2동    9831
# ...

# %% [markdown]
# ## 지도에 표시해보기

# %%
import json
import folium
import warnings
warnings.simplefilter(action = "ignore", category = FutureWarning)

# 그래프에 retina display 적용

# %%
# geo_path = 'HangJeongDong_ver20160201.json'
geo_path = 'HangJeongDong.json'

geo_str = json.load(open(geo_path, encoding='utf-8'))
#geo_str

# %%
geo_df = df_seoul

# %%
geo_df['위도'] = geo_df['위도'].astype(float)
geo_df['경도'] = geo_df['경도'].astype(float)
# Out:
# /Users/jieun/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/jieun/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
geo_df.head(2)
# Out:
#    Unnamed: 0              주소  총인구 (명)  남자 (명)  여자 (명)  내국인-계 (명)  내국인-남자 (명)  \
# 0           0  서울특별시 종로구  사직동     9379    4325    5054       8571        3934
# 1           1  서울특별시 종로구  삼청동     2808    1340    1468       2601        1222
#
#    내국인-여자 (명) 외국인-계 (명) 외국인-남자 (명)   ...    아파트 (호)  연립주택 (호)  다세대주택 (호)  \
# 0        4637       808        391   ...       1532        78        386
# 1        1379       207        118   ...          X        19         41
#
#   비거주용 건물내 주택 (호) 주택이외의 거처 (호)         위도          경도           juso counts  \
# 0              46          633  37.576164  126.968806  서울특별시 종로구 사직동   9379
# 1              25           35  37.584838  126.981913  서울특별시 종로구 삼청동   2808
#
#   인구수(str)
# 0     9379
# 1     2808
#
# [2 rows x 27 columns]

# %%
map = folium.Map(location=[geo_df['위도'].mean(), geo_df['경도'].mean()], zoom_start=17, tiles='Stamen Toner')
map


guDat = pd.DataFrame({'juso':geo_df['juso'], 'counts':geo_df['counts']})

# %%
guDat
# Out:
#                       juso  counts
# 0            서울특별시 종로구 사직동    9379
# 1            서울특별시 종로구 삼청동    2808
# 2            서울특별시 종로구 부암동   11012
# 3            서울특별시 종로구 평창동   18594
# 4            서울특별시 종로구 무악동    8106
# 5            서울특별시 종로구 교남동    4620
# 6            서울특별시 종로구 가회동    4917
# 7    서울특별시 종로구 종로1·2·3·4가동    7598
# 8        서울특별시 종로구 종로5·6가동    5792
# 9            서울특별시 종로구 이화동    9519
# 10          서울특별시 종로구 창신1동    6766
# 11          서울특별시 종로구 창신2동   11405
# 12          서울특별시 종로구 창신3동    7603
# 13          서울특별시 종로구 숭인1동    7049
# 14          서울특별시 종로구 숭인2동    9831
# 15         서울특별시 종로구 청운효자동   13580
# 16           서울특별시 종로구 혜화동   22942
# 17            서울특별시 중구 소공동    1939
# 18            서울특별시 중구 회현동    5501
# 19             서울특별시 중구 명동    3328
# 20             서울특별시 중구 필동    5506
# 21            서울특별시 중구 장충동    6216
# 22            서울특별시 중구 광희동    5594
# 23           서울특별시 중구 을지로동    1543
# 24           서울특별시 중구 신당5동   10138
# 25            서울특별시 중구 황학동   12700
# ...

# %%
geo_df['인구수(str)'] = geo_df['총인구 (명)'].astype(str)  # int형은 마커로 찍을 때 에러가 나서 str로 바꿔준다.
# Out:
# /Users/jieun/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
geo_df['인구수(str)'].head()
# Out:
# 0     9379
# 1     2808
# 2    11012
# 3    18594
# 4     8106
# Name: 인구수(str), dtype: object

# %%
geo_str['features'] = [f for f in geo_str['features'] if f['properties']['adm_nm'].startswith('서울특별시')]
# Out:
# 424

# %%
geo_df.describe()
# Out:
#        Unnamed: 0       총인구 (명)        남자 (명)        여자 (명)     내국인-계 (명)  \
# count   424.00000    424.000000    424.000000    424.000000    424.000000
# mean    211.50000  23359.226415  11461.167453  11898.058962  22564.141509
# std     122.54251   9065.274814   4434.579079   4658.514507   9013.046330
# min       0.00000    746.000000    381.000000    365.000000    739.000000
# 25%     105.75000  17501.000000   8632.500000   8974.500000  16877.750000
# 50%     211.50000  22655.000000  11082.500000  11489.500000  21831.000000
# 75%     317.25000  28633.500000  14014.000000  14746.750000  27999.500000
# max     423.00000  53880.000000  26672.000000  27208.000000  52480.000000
#
#          내국인-남자 (명)    내국인-여자 (명)     가구-계 (가구)     일반가구 (가구)      주택-계 (호)  \
# count    424.000000    424.000000    424.000000    424.000000    424.000000
# mean   11071.502358  11492.639151   9233.066038   8925.683962   6587.839623
# ...

# %%
DT = pd.read_csv('seoul_DT.csv')
DT = pd.DataFrame(DT)

# %%
DT.head()
# Out:
#            지점명                도로명주소   Latitude   Longitude  dt
# 0  여의도IFC몰(B3)  서울특별시 영등포구 국제금융로 10  37.524937  126.925285   0
# 1          연신내    서울특별시 은평구 통일로 867  37.620192  126.919881   0
# 2      강남대로논현R  서울특별시 서초구 강남대로85길 5  37.507328  127.022582   0
# 3           미아   서울특별시 성북구 동소문로 314  37.607581  127.029303   0
# 4          공릉역   서울특별시 노원구 동일로 1081  37.626337  127.072252   0

# %%
for i in range(len(DT)):
    if DT['dt'][i] == 0:
        DT = DT.drop([i])

# %%
seoul_DT = DT
seoul_DT.head()
# Out:
#      지점명                 도로명주소   Latitude   Longitude  dt
# 44  방화DT    서울특별시 강서구 방화대로 375  37.574339  126.816415   1
# 48  종암DT      서울특별시 성북구 종암로 17  37.591953  127.036040   1
# 61  신정DT     서울특별시 양천구 신월로 341  37.519801  126.848743   1
# 66  신림DT  서울특별시 관악구 남부순환로 1419  37.480935  126.908407   1
# 77  공릉DT    서울특별시 노원구 동일로 1015  37.620688  127.074312   1

# %%
seoul_DT['동주소'] = 0

# %%
seoul_DT['동주소'][0] = '서울특별시 강서구 방화3동'
seoul_DT['동주소'][1] = '서울특별시 성북구 종암동'
seoul_DT['동주소'][2] = '서울특별시 양천구 신정4동'
seoul_DT['동주소'][3] = '서울특별시 관악구 신림동'
seoul_DT['동주소'][4] = '서울특별시 노원구 공릉1동'
seoul_DT['동주소'][5] = '서울특별시 영등포구 신길5동'
seoul_DT['동주소'][6] = '서울특별시 서대문구 연희동 '


seoul_DT['동주소'][7] = '서울특별시 광진구 구의2동'
seoul_DT['동주소'][8] = '서울특별시 양천구 신월3동'
seoul_DT['동주소'][9] = '서울특별시 강서구 화곡4동'
seoul_DT['동주소'][10] = '서울특별시 관악구 인헌동'
seoul_DT['동주소'][11] = '서울특별시 송파구 방이1동'
# Out:
# /Users/jieun/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/jieun/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/jieun/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
seoul_DT = seoul_DT.reset_index(drop=True)

# %%
seoul_DT
# Out:
#         지점명                 도로명주소   Latitude   Longitude  dt              동주소  \
# 0      방화DT    서울특별시 강서구 방화대로 375  37.574339  126.816415   1   서울특별시 강서구 방화3동
# 1      종암DT      서울특별시 성북구 종암로 17  37.591953  127.036040   1    서울특별시 성북구 종암동
# 2      신정DT     서울특별시 양천구 신월로 341  37.519801  126.848743   1   서울특별시 양천구 신정4동
# 3      신림DT  서울특별시 관악구 남부순환로 1419  37.480935  126.908407   1    서울특별시 관악구 신림동
# 4      공릉DT    서울특별시 노원구 동일로 1015  37.620688  127.074312   1   서울특별시 노원구 공릉1동
# 5   영등포신길DT    서울특별시 영등포구 신길로 137  37.504557  126.910074   1  서울특별시 영등포구 신길5동
# 6      연희DT    서울특별시 서대문구 연희로 144  37.570118  126.933859   1  서울특별시 서대문구 연희동
# 7      구의DT    서울특별시 광진구 광나루로 519  37.545357  127.087171   1   서울특별시 광진구 구의2동
# 8    신월ICDT   서울특별시 양천구 남부순환로 430  37.529391  126.832056   1   서울특별시 양천구 신월3동
# 9      화곡DT      서울특별시 강서구 등촌로 57  37.550737  126.863296   1   서울특별시 강서구 화곡4동
# 10    낙성대DT  서울특별시 관악구 남부순환로 1948  37.476169  126.965005   1    서울특별시 관악구 인헌동
# ...

# %%
seoul = seoul_DT['동주소']

# %%
type(seoul)
# Out:
# pandas.core.series.Series

# %%
geo_df['juso'][0]
# Out:
# '서울특별시 종로구 사직동'

# %%
geo_df.loc[geo_df['juso'].str.contains('서울특별시 성북구 종암동')]
# Out:
#      Unnamed: 0              주소  총인구 (명)  남자 (명)  여자 (명)  내국인-계 (명)  \
# 128         128  서울특별시 성북구  종암동    41820   20505   21315      40360
#
#      내국인-남자 (명)  내국인-여자 (명) 외국인-계 (명) 외국인-남자 (명)   ...    아파트 (호)  연립주택 (호)  \
# 128       19912       20448      1460        593   ...       8030       370
#
#      다세대주택 (호) 비거주용 건물내 주택 (호) 주택이외의 거처 (호)         위도          경도  \
# 128       1571             116          153  37.600171  127.031602
#
#               juso counts 인구수(str)
# 128  서울특별시 성북구 종암동  41820    41820
#
# [1 rows x 27 columns]

# %%
seoul_DT['인구수'][11] = geo_df['인구수(str)'].loc[geo_df['juso'] == '서울특별시 송파구 방이1동']
# Out:
# /Users/jieun/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
seoul_DT['동주소']
# Out:
# 0      서울특별시 강서구 방화3동
# 1       서울특별시 성북구 종암동
# 2      서울특별시 양천구 신정4동
# 3       서울특별시 관악구 신림동
# 4      서울특별시 노원구 공릉1동
# 5     서울특별시 영등포구 신길5동
# 6     서울특별시 서대문구 연희동
# 7      서울특별시 광진구 구의2동
# 8      서울특별시 양천구 신월3동
# 9      서울특별시 강서구 화곡4동
# 10      서울특별시 관악구 인헌동
# 11     서울특별시 송파구 방이1동
# Name: 동주소, dtype: object

# %%
seoul_DT['인구수'] = seoul_DT['인구수'].astype(str)

# %%
# 최종 전처리 된 csv 가져오기 

cleaned_seoul_DT = pd.read_csv('cleaned_seoulDT.csv')

# %%
cleaned_seoul_DT.describe()
# Out:
#        Unnamed: 0   Latitude   Longitude    dt           인구수      아파트수(호)  \
# count   12.000000  12.000000   12.000000  12.0     12.000000    12.000000
# mean   110.000000  37.539216  126.949659   1.0  27235.666667  3104.666667
# std     55.180695   0.044611    0.106210   0.0   9631.371736  3325.470229
# min     44.000000  37.476169  126.816415   1.0  15696.000000   450.000000
# 25%     64.750000  37.506050  126.859657   1.0  19271.750000   788.500000
# 50%    105.000000  37.537374  126.921966   1.0  24925.500000  1566.500000
# 75%    138.250000  37.571174  127.045608   1.0  36191.750000  4304.000000
# max    197.000000  37.620688  127.120526   1.0  41820.000000  8831.000000
#
#           다세대주택(호)
# count    12.000000
# mean   2555.333333
# std    1472.874761
# min     484.000000
# 25%    1517.000000
# 50%    2327.500000
# 75%    3730.250000
# max    4926.000000

# %%
guDat['counts'].max()
# Out:
# 53880

# %%
guDat['counts'].min()
# Out:
# 746

# %%
import branca.colormap as cm

colormap = cm.LinearColormap(colors=['blue','purple','red'],vmin=746,vmax=53880)
colormap
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#0000ff;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#0000ff;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#0100fe;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#0100fe;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#0200fd;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#0200fd;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#0300fc;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#0300fc;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#0400fb;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#0400fb;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#0500fa;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#0500fa;stroke-width:3;" /><line x1="12" y1="0" x2="12" y2="20" style="stroke:#0
# ...

# %%
colormap = cm.linear.Set1.scale(0,35).to_step(10)
colormap.caption = 'A colormap caption'
map.add_children(colormap)

colormap = colormap.scale(0,35).to_step(10)
colormap.caption = 'A colormap caption'
map.add_children(colormap)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-428-bb4887c3720e> in <module>()
#       1 m = folium.Map(tiles='cartodbpositron')
#       2
# ----> 3 colormap = cm.linear.Set1.scale(0,35).to_step(10)
#       4 colormap.caption = 'A colormap caption'
#       5 m.add_children(colormap)
#
# AttributeError: '_LinearColormaps' object has no attribute 'Set1'

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11, tiles='Stamen Toner')
map.choropleth(
    geo_data=geo_str,
    data=guDat,
    columns=['juso','counts'],
    fill_color= 'RdYlBu', #PuRd, YlGnBu   Paired
    key_on='feature.properties.adm_nm',
    threshold_scale=[1000,17000,26000,28000,55000],
    legend_name='인구수(명), 2015년 기준'
)


for i, row in seoul_DT.iterrows():
    mall_name = row['지점명'] + ' / ' + '인구수 : ' + row['인구수'] + '명 / ' + ' 주소 : ' + row['동주소']
    
    folium.Marker(
        [row['Latitude'], row['Longitude']], 
        popup=mall_name,
        icon=folium.Icon(color='red'),
    ).add_to(map)
    
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map.save('map_counts.html')
